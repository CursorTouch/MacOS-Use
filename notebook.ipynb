# %%
from macos_use.agent.desktop.service import Desktop
from time import time,sleep

# %%
desktop=Desktop()

# %%
sleep(5)
desktop_state=desktop.get_state(use_vision=True)

# %%
desktop_state.screenshot
# Out:
# <PIL.Image.Image image mode=RGB size=2887x1807>

# %%
print(desktop_state.active_window_to_string())
# Out:
# Name    Status      Width    Height  Bundle ID
# ------  --------  -------  --------  -----------------------------
# Cursor  Normal       1259       651  com.todesktop.230313mzl4w4u92

# %%
print(desktop_state.windows_to_string())
# Out:
# Name                     Status       Width    Height  Bundle ID
# -----------------------  ---------  -------  --------  --------------------------------
# Google Chrome            Normal        1381       796  com.google.Chrome
# Antigravity              Normal        1440       796  com.google.antigravity
# Finder                   Normal         920       436  com.apple.finder
# Spotify                  Minimized        0         0  com.spotify.client
# Cursor                   Normal        1259       651  com.todesktop.230313mzl4w4u92
# Accessibility Inspector  Minimized        0         0  com.apple.AccessibilityInspector

# %%
print(desktop_state.tree_state.interactive_elements_to_string())
# Out:
# # id|window|role|name|coords|metadata
# 0|Spotlight|AXMenuBarItem|Spotlight|(1233,15)|{'is_focused': False, 'type': 'status menu', 'subrole': 'AXMenuExtra'}
# 1|MenuBar|AXMenuBarItem|Apple|(27,15)|{'is_focused': False, 'type': 'menu bar item'}
# 2|MenuBar|AXMenuBarItem|Cursor|(76,15)|{'is_focused': False, 'type': 'menu bar item'}
# 3|MenuBar|AXMenuBarItem|File|(129,15)|{'is_focused': False, 'type': 'menu bar item'}
# 4|MenuBar|AXMenuBarItem|Edit|(172,15)|{'is_focused': False, 'type': 'menu bar item'}
# 5|MenuBar|AXMenuBarItem|Selection|(232,15)|{'is_focused': False, 'type': 'menu bar item'}
# 6|MenuBar|AXMenuBarItem|View|(296,15)|{'is_focused': False, 'type': 'menu bar item'}
# 7|MenuBar|AXMenuBarItem|Go|(340,15)|{'is_focused': False, 'type': 'menu bar item'}
# 8|MenuBar|AXMenuBarItem|Run|(381,15)|{'is_focused': False, 'type': 'menu bar item'}
# 9|MenuBar|AXMenuBarItem|Terminal|(439,15)|{'is_focused': False, 'type': 'menu bar item'}
# 10|MenuBar|AXMenuBarItem|Window|(509,15)|{'is_focused': False, 'type': 'menu bar item'}
# 11|MenuBar|AXMenuBarItem|Help|(568,15)|{'is_focused': False, 'type': 'menu bar item'}
# 12|Dock|AXDockItem|Finder|(358,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 13|Dock|AXDockItem|Antigravity|(410,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 14|Dock|AXDockItem|Apps|(462,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 15|Dock|AXDockItem|Steam|(514,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 16|Dock|AXDockItem|Spotify|(566,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 17|Dock|AXDockItem|WhatsApp|(618,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 18|Dock|AXDockItem|Claude|(670,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 19|Dock|AXDockItem|Google Chrome|(722,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 20|Dock|AXDockItem|App Store|(774,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 21|Dock|AXDockItem|Cursor|(826,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 22|Dock|AXDockItem|System Settings|(878,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 23|Dock|AXDockItem|0.2857142984867096|(916,856)|{'is_focused': False, 'type': 'separator dock item', 'subrole': 'AXSeparatorDockItem'}
# 24|Dock|AXDockItem|Accessibility Inspector|(954,856)|{'is_focused': False, 'type': 'application dock item', 'subrole': 'AXApplicationDockItem'}
# 25|Dock|AXDockItem|0.2857142984867096|(991,856)|{'is_focused': False, 'type': 'separator dock item', 'subrole': 'AXSeparatorDockItem'}
# 26|Dock|AXDockItem|Accessibility Inspector|(1029,856)|{'is_focused': False, 'type': 'minimised window dock item', 'subrole': 'AXMinimizedWindowDockItem'}
# 27|Dock|AXDockItem|Bin|(1081,856)|{'is_focused': False, 'type': 'bin dock item', 'subrole': 'AXTrashDockItem'}
# 28|Control Center|AXMenuBarItem|Battery|(1196,15)|{'is_focused': False, 'type': 'status menu', 'subrole': 'AXMenuExtra'}
# 29|Control Center|AXMenuBarItem|Clock|(1365,15)|{'is_focused': False, 'type': 'status menu', 'subrole': 'AXMenuExtra'}
# 30|Control Center|AXMenuBarItem|Wi‑Fi, connected, 3 bars|(1156,15)|{'is_focused': False, 'type': 'status menu', 'subrole': 'AXMenuExtra'}
# 31|Control Center|AXMenuBarItem|Control Centre|(1270,15)|{'is_focused': False, 'type': 'status menu', 'subrole': 'AXMenuExtra'}
# 32|Control Center|AXMenuBarItem|Now Playing|(1120,15)|{'is_focused': False, 'type': 'status menu', 'subrole': 'AXMenuExtra'}
# 33|notebook.ipynb — Macos-Use|AXButton|Go Back (⌃-)|(175,47)|{'is_focused': False, 'type': 'button'}
# 34|notebook.ipynb — Macos-Use|AXButton|Macos-Use|(711,47)|{'is_focused': False, 'type': 'button'}
# 35|notebook.ipynb — Macos-Use|AXButton|New Agent (⌘N)|(1226,47)|{'is_focused': False, 'type': 'button'}
# 36|notebook.ipynb — Macos-Use|AXCheckBox|Toggle Primary Side Bar (⌘B)|(1250,47)|{'is_focused': False, 'type': 'Tick box'}
# 37|notebook.ipynb — Macos-Use|AXCheckBox|Toggle Panel (⌘J)|(1274,47)|{'is_focused': False, 'type': 'Tick box'}
# 38|notebook.ipynb — Macos-Use|AXButton|Toggle Agents Side Bar (⌥⌘S)|(1298,47)|{'is_focused': False, 'type': 'button'}
# 39|notebook.ipynb — Macos-Use|AXButton|Change Layout|(1322,47)|{'is_focused': False, 'type': 'button'}
# 40|notebook.ipynb — Macos-Use|AXButton|Explorer Section: Macos-Use|(216,111)|{'is_focused': False, 'type': 'button'}
# 41|notebook.ipynb — Macos-Use|AXRow|views.py|(216,120)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 42|notebook.ipynb — Macos-Use|AXRow|ax|(216,142)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 43|notebook.ipynb — Macos-Use|AXRow|__pycache__|(216,164)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 44|notebook.ipynb — Macos-Use|AXRow|__init__.py|(216,186)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 45|notebook.ipynb — Macos-Use|AXRow|controls.py|(216,208)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 46|notebook.ipynb — Macos-Use|AXRow|core.py|(216,230)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 47|notebook.ipynb — Macos-Use|AXRow|enums.py|(216,252)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 48|notebook.ipynb — Macos-Use|AXRow|events.py|(216,274)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 49|notebook.ipynb — Macos-Use|AXRow|patterns.py|(216,296)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 50|notebook.ipynb — Macos-Use|AXRow|llms|(216,318)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 51|notebook.ipynb — Macos-Use|AXRow|messages|(216,340)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 52|notebook.ipynb — Macos-Use|AXRow|telemetry|(216,362)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 53|notebook.ipynb — Macos-Use|AXRow|tool|(216,384)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 54|notebook.ipynb — Macos-Use|AXRow|__init__.py|(216,406)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 55|notebook.ipynb — Macos-Use|AXRow|.env|(216,428)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 56|notebook.ipynb — Macos-Use|AXRow|.gitignore|(216,450)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 57|notebook.ipynb — Macos-Use|AXRow|.python-version|(216,472)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 58|notebook.ipynb — Macos-Use|AXRow|main.py|(216,494)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 59|notebook.ipynb — Macos-Use|AXRow|notebook.ipynb|(216,516)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 60|notebook.ipynb — Macos-Use|AXRow|pyproject.toml|(216,538)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 61|notebook.ipynb — Macos-Use|AXRow|README.md|(216,560)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 62|notebook.ipynb — Macos-Use|AXRow|uv.lock|(216,582)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 63|notebook.ipynb — Macos-Use|AXRow|ax|(216,155)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 64|notebook.ipynb — Macos-Use|AXRow|macos_use|(216,133)|{'is_focused': False, 'type': 'outline row', 'subrole': 'AXOutlineRow'}
# 65|notebook.ipynb — Macos-Use|AXButton|Outline Section|(216,626)|{'is_focused': False, 'type': 'button'}
# 66|notebook.ipynb — Macos-Use|AXButton|Timeline Section|(216,648)|{'is_focused': False, 'type': 'button'}
# 67|notebook.ipynb — Macos-Use|AXRadioButton|main.py|(406,82)|{'is_focused': False, 'type': 'tab', 'subrole': 'AXTabButton'}
# 68|notebook.ipynb — Macos-Use|AXRadioButton|service.py|(533,82)|{'is_focused': False, 'type': 'tab', 'subrole': 'AXTabButton'}
# 69|notebook.ipynb — Macos-Use|AXRadioButton|views.py|(671,82)|{'is_focused': False, 'type': 'tab', 'subrole': 'AXTabButton'}
# 70|notebook.ipynb — Macos-Use|AXRadioButton|notebook.ipynb|(825,82)|{'is_focused': False, 'type': 'tab', 'subrole': 'AXTabButton'}
# 71|notebook.ipynb — Macos-Use|AXButton|Open Changes|(1274,82)|{'is_focused': False, 'type': 'button'}
# 72|notebook.ipynb — Macos-Use|AXButton|Split Editor Right (⌘\) [⌥] Split Editor Down|(1298,82)|{'is_focused': False, 'type': 'button'}
# 73|notebook.ipynb — Macos-Use|AXLink|More Actions...|(1322,82)|{'is_focused': False, 'type': 'link'}
# 74|notebook.ipynb — Macos-Use|AXButton|remote|(99,670)|{'is_focused': False, 'type': 'button'}
# 75|notebook.ipynb — Macos-Use|AXButton|Macos-Use (Git) - master*, Checkout Branch/Tag...|(153,670)|{'is_focused': False, 'type': 'button'}
# 76|notebook.ipynb — Macos-Use|AXButton|Macos-Use (Git) - Synchronize Changes|(197,670)|{'is_focused': False, 'type': 'button'}
# 77|notebook.ipynb — Macos-Use|AXButton|Workspace: Macos-Use|(250,670)|{'is_focused': False, 'type': 'button'}
# 78|notebook.ipynb — Macos-Use|AXButton|No Problems|(326,670)|{'is_focused': False, 'type': 'button'}
# 79|notebook.ipynb — Macos-Use|AXButton|Notifications|(1319,670)|{'is_focused': False, 'type': 'button'}
# 80|notebook.ipynb — Macos-Use|AXButton|Cell 7 of 7|(1267,670)|{'is_focused': False, 'type': 'button'}
# 81|notebook.ipynb — Macos-Use|AXButton|LF|(1215,670)|{'is_focused': False, 'type': 'button'}
# 82|notebook.ipynb — Macos-Use|AXButton|Spaces: 4|(1164,670)|{'is_focused': False, 'type': 'button'}
# 83|notebook.ipynb — Macos-Use|AXButton|Spaces: 4|(1092,670)|{'is_focused': False, 'type': 'button'}
# 84|notebook.ipynb — Macos-Use|AXButton|Ln 2, Col 28|(1014,670)|{'is_focused': False, 'type': 'button'}
# 85|notebook.ipynb — Macos-Use|AXButton|Cursor Tab|(933,670)|{'is_focused': False, 'type': 'button'}
# 86|notebook.ipynb — Macos-Use|AXLink|Go To|(787,145)|{'is_focused': False, 'type': 'link'}
# 87|notebook.ipynb — Macos-Use|AXLink|More Actions...|(993,145)|{'is_focused': False, 'type': 'link'}
# 88|notebook.ipynb — Macos-Use|AXButton|.venv (Python 3.13.12)|(1255,145)|{'is_focused': False, 'type': 'button'}
# 89|notebook.ipynb — Macos-Use|AXButton|Execute Cell (⌃⏎)|(370,193)|{'is_focused': False, 'type': 'button'}
# 90|notebook.ipynb — Macos-Use|AXLink|More...|(386,193)|{'is_focused': False, 'type': 'link'}
# 91|notebook.ipynb — Macos-Use|AXTextArea|The editor is not accessible at this time. To enable screen reader optimized mode, use Shift+Option+F1|(623,221)|{'is_focused': False, 'type': 'editor'}
# 92|notebook.ipynb — Macos-Use|AXButton|Add Code ⌘⏎|(795,264)|{'is_focused': False, 'type': 'button'}
# 93|notebook.ipynb — Macos-Use|AXButton|Add Markdown|(892,264)|{'is_focused': False, 'type': 'button'}
# 94|notebook.ipynb — Macos-Use|AXTextArea|The editor is not accessible at this time. To enable screen reader optimized mode, use Shift+Option+F1|(428,305)|{'is_focused': False, 'type': 'editor'}
# 95|notebook.ipynb — Macos-Use|AXButton|Add Code ⌘⏎|(795,348)|{'is_focused': False, 'type': 'button'}
# 96|notebook.ipynb — Macos-Use|AXButton|Add Markdown|(892,348)|{'is_focused': False, 'type': 'button'}
# 97|notebook.ipynb — Macos-Use|AXTextArea|The editor is not accessible at this time. To enable screen reader optimized mode, use Shift+Option+F1|(428,389)|{'is_focused': False, 'type': 'editor'}
# 98|notebook.ipynb — Macos-Use|AXButton|Add Code ⌘⏎|(795,450)|{'is_focused': False, 'type': 'button'}
# 99|notebook.ipynb — Macos-Use|AXButton|Add Markdown|(892,450)|{'is_focused': False, 'type': 'button'}
# 100|notebook.ipynb — Macos-Use|AXTextArea|The editor is not accessible at this time. To enable screen reader optimized mode, use Shift+Option+F1|(428,491)|{'is_focused': False, 'type': 'editor'}
# 101|notebook.ipynb — Macos-Use|AXButton|Add Code ⌘⏎|(795,534)|{'is_focused': False, 'type': 'button'}
# 102|notebook.ipynb — Macos-Use|AXButton|Add Markdown|(892,534)|{'is_focused': False, 'type': 'button'}
# 103|notebook.ipynb — Macos-Use|AXTextArea|The editor is not accessible at this time. To enable screen reader optimized mode, use Shift+Option+F1|(428,575)|{'is_focused': False, 'type': 'editor'}
# 104|notebook.ipynb — Macos-Use|AXButton|Add Code ⌘⏎|(795,618)|{'is_focused': False, 'type': 'button'}
# 105|notebook.ipynb — Macos-Use|AXButton|Add Markdown|(892,618)|{'is_focused': False, 'type': 'button'}
# 106|notebook.ipynb — Macos-Use|AXTextArea|The editor is not accessible at this time. To enable screen reader optimized mode, use Shift+Option+F1|(428,654)|{'is_focused': False, 'type': 'editor'}
# 107|notebook.ipynb — Macos-Use|AXButton|Close Button|(100,47)|{'is_focused': False, 'type': 'close button', 'subrole': 'Close Button'}
# 108|notebook.ipynb — Macos-Use|AXButton|Full Screen Button|(146,47)|{'is_focused': False, 'type': 'full screen button', 'subrole': 'Full Screen Button'}
# 109|notebook.ipynb — Macos-Use|AXButton|Minimize Button|(123,47)|{'is_focused': False, 'type': 'minimise button', 'subrole': 'Minimize Button'}
